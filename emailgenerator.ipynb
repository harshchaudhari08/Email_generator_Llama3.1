# %%
# !pip install langchain
# Out:
# Collecting langchain
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# streamlit 1.28.2 requires packaging<24,>=16.8, but you have packaging 24.1 which is incompatible.
# jupyter-server 1.13.5 requires pywinpty<2; os_name == "nt", but you have pywinpty 2.0.2 which is incompatible.
# arviz 0.11.2 requires typing-extensions<4,>=3.7.4.3, but you have typing-extensions 4.8.0 which is incompatible.
#   Downloading langchain-0.2.16-py3-none-any.whl (1.0 MB)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\asus\anaconda3\lib\site-packages (from langchain) (1.4.32)
# Collecting langchain-core<0.3.0,>=0.2.38
#   Downloading langchain_core-0.2.38-py3-none-any.whl (396 kB)
# Collecting aiohttp<4.0.0,>=3.8.3
#   Downloading aiohttp-3.10.5-cp39-cp39-win_amd64.whl (379 kB)
# Collecting langsmith<0.2.0,>=0.1.17
#   Downloading langsmith-0.1.112-py3-none-any.whl (288 kB)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in c:\users\asus\anaconda3\lib\site-packages (from langchain) (4.0.1)
# Requirement already satisfied: numpy<2,>=1 in c:\users\asus\anaconda3\lib\site-packages (from langchain) (1.26.3)
# Collecting pydantic<3,>=1
#   Downloading pydantic-2.8.2-py3-none-any.whl (423 kB)
# Requirement already satisfied: requests<3,>=2 in c:\users\asus\anaconda3\lib\site-packages (from langchain) (2.27.1)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in c:\users\asus\anaconda3\lib\site-packages (from langchain) (8.2.3)
# Collecting langchain-text-splitters<0.3.0,>=0.2.0
#   Downloading langchain_text_splitters-0.2.4-py3-none-any.whl (25 kB)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\asus\anaconda3\lib\site-packages (from langchain) (6.0)
# Collecting aiohappyeyeballs>=2.3.0
#   Downloading aiohappyeyeballs-2.4.0-py3-none-any.whl (12 kB)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\asus\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (5.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\asus\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.2.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\asus\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\asus\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (21.4.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\asus\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.6.3)
# Requirement already satisfied: typing-extensions>=3.6.5 in c:\users\asus\anaconda3\lib\site-packages (from async-timeout<5.0.0,>=4.0.0->langchain) (4.8.0)
# Collecting packaging<25,>=23.2
#   Downloading packaging-24.1-py3-none-any.whl (53 kB)
# Collecting jsonpatch<2.0,>=1.33
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Collecting jsonpointer>=1.9
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Collecting httpx<1,>=0.23.0
#   Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
# Collecting orjson<4.0.0,>=3.9.14
#   Downloading orjson-3.10.7-cp39-none-win_amd64.whl (137 kB)
# Requirement already satisfied: sniffio in c:\users\asus\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.2.0)
# Requirement already satisfied: idna in c:\users\asus\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (3.3)
# Requirement already satisfied: certifi in c:\users\asus\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (2021.10.8)
# Requirement already satisfied: anyio in c:\users\asus\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (3.5.0)
# Collecting httpcore==1.*
#   Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
# Collecting h11<0.15,>=0.13
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
# Collecting pydantic-core==2.20.1
#   Downloading pydantic_core-2.20.1-cp39-none-win_amd64.whl (1.9 MB)
# Collecting annotated-types>=0.4.0
#   Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\asus\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\asus\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (2.0.4)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\asus\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (1.1.1)
# Installing collected packages: h11, pydantic-core, httpcore, annotated-types, pydantic, orjson, jsonpointer, httpx, packaging, langsmith, jsonpatch, langchain-core, aiohappyeyeballs, langchain-text-splitters, aiohttp, langchain
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic-core 2.14.6
#     Uninstalling pydantic-core-2.14.6:
#       Successfully uninstalled pydantic-core-2.14.6
#   Attempting uninstall: packaging
#     Found existing installation: packaging 21.3
#     Uninstalling packaging-21.3:
#       Successfully uninstalled packaging-21.3
#   Attempting uninstall: aiohttp
#     Found existing installation: aiohttp 3.8.1
#     Uninstalling aiohttp-3.8.1:
#       Successfully uninstalled aiohttp-3.8.1
# Successfully installed aiohappyeyeballs-2.4.0 aiohttp-3.10.5 annotated-types-0.7.0 h11-0.14.0 httpcore-1.0.5 httpx-0.27.2 jsonpatch-1.33 jsonpointer-3.0.0 langchain-0.2.16 langchain-core-0.2.38 langchain-text-splitters-0.2.4 langsmith-0.1.112 orjson-3.10.7 packaging-24.1 pydantic-2.8.2 pydantic-core-2.20.1

# %%
# !pip install langchain-groq
# Out:
# Collecting langchain-groq
#   Downloading langchain_groq-0.1.9-py3-none-any.whl (14 kB)
# Collecting groq<1,>=0.4.1
#   Downloading groq-0.11.0-py3-none-any.whl (106 kB)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.26 in c:\users\asus\anaconda3\lib\site-packages (from langchain-groq) (0.2.38)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\asus\anaconda3\lib\site-packages (from groq<1,>=0.4.1->langchain-groq) (2.8.2)
# Requirement already satisfied: typing-extensions<5,>=4.7 in c:\users\asus\anaconda3\lib\site-packages (from groq<1,>=0.4.1->langchain-groq) (4.8.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\asus\anaconda3\lib\site-packages (from groq<1,>=0.4.1->langchain-groq) (3.5.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\asus\anaconda3\lib\site-packages (from groq<1,>=0.4.1->langchain-groq) (0.27.2)
# Collecting distro<2,>=1.7.0
#   Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: sniffio in c:\users\asus\anaconda3\lib\site-packages (from groq<1,>=0.4.1->langchain-groq) (1.2.0)
# Requirement already satisfied: idna>=2.8 in c:\users\asus\anaconda3\lib\site-packages (from anyio<5,>=3.5.0->groq<1,>=0.4.1->langchain-groq) (3.3)
# Requirement already satisfied: certifi in c:\users\asus\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq) (2021.10.8)
# Requirement already satisfied: httpcore==1.* in c:\users\asus\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\asus\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq) (0.14.0)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in c:\users\asus\anaconda3\lib\site-packages (from langchain-core<0.3.0,>=0.2.26->langchain-groq) (8.2.3)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.75 in c:\users\asus\anaconda3\lib\site-packages (from langchain-core<0.3.0,>=0.2.26->langchain-groq) (0.1.112)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\asus\anaconda3\lib\site-packages (from langchain-core<0.3.0,>=0.2.26->langchain-groq) (24.1)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\asus\anaconda3\lib\site-packages (from langchain-core<0.3.0,>=0.2.26->langchain-groq) (6.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\asus\anaconda3\lib\site-packages (from langchain-core<0.3.0,>=0.2.26->langchain-groq) (1.33)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\asus\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.26->langchain-groq) (3.0.0)
# Requirement already satisfied: requests<3,>=2 in c:\users\asus\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.75->langchain-core<0.3.0,>=0.2.26->langchain-groq) (2.27.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\asus\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.75->langchain-core<0.3.0,>=0.2.26->langchain-groq) (3.10.7)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\asus\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->groq<1,>=0.4.1->langchain-groq) (2.20.1)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\asus\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->groq<1,>=0.4.1->langchain-groq) (0.7.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\asus\anaconda3\lib\site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.75->langchain-core<0.3.0,>=0.2.26->langchain-groq) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\asus\anaconda3\lib\site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.75->langchain-core<0.3.0,>=0.2.26->langchain-groq) (1.26.9)
# Installing collected packages: distro, groq, langchain-groq
# Successfully installed distro-1.9.0 groq-0.11.0 langchain-groq-0.1.9

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(
    temperature=0,
    groq_api_key = "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",
    model_name="llama-3.1-70b-versatile",
    
)

response = llm.invoke("Write me an email to apply for a barista position at Hill of beans cafe.")
print(response.content)
# Out:
# Subject: Application for Barista Position at Hill of Beans Cafe
#
# Dear Hiring Manager,
#
# I am writing to express my interest in the Barista position at Hill of Beans Cafe. As a coffee enthusiast with a passion for delivering exceptional customer service, I am confident that I would be a great fit for your team.
#
# With [number] years of experience in the food and beverage industry, I possess the skills and knowledge required to excel as a barista. My previous experience has taught me the importance of attention to detail, multitasking, and maintaining a clean and organized workspace. I am well-versed in coffee preparation methods, including espresso, pour-overs, and latte art.
#
# I am particularly drawn to Hill of Beans Cafe because of its commitment to serving high-quality coffee and creating a welcoming atmosphere for customers. I am impressed by the cafe's dedication to using sustainable and locally sourced ingredients, and I am excited about the opportunity to be a part of a team that shares my values.
#
# In addition to my technical skills and experience, I possess excellent communication and interpersonal skills, which enable me to build strong relationships with customers and colleagues alike. I am a team player who is always willing to lend a hand and support my colleagues during busy periods.
#
# I have attached my resume for your review. I would welcome the opportunity to discuss my application and how I can contribute to the success of Hill of Beans Cafe. Please do not hesitate to contact me if you require any further information.
#
# Thank you for considering my application. I look forward to the opportunity to meet with you and discuss how I can join the Hill of Beans Cafe team.
#
# Sincerely,
#
# [Your Name]

# %%
# !pip install chromadb
# Out:
# Collecting chromadb
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# streamlit 1.28.2 requires importlib-metadata<7,>=1.4, but you have importlib-metadata 8.4.0 which is incompatible.
# streamlit 1.28.2 requires packaging<24,>=16.8, but you have packaging 24.1 which is incompatible.
#   Downloading chromadb-0.5.5-py3-none-any.whl (584 kB)
# Collecting posthog>=2.4.0
#   Downloading posthog-3.6.3-py2.py3-none-any.whl (53 kB)
# Requirement already satisfied: pydantic>=1.9 in c:\users\asus\anaconda3\lib\site-packages (from chromadb) (2.8.2)
# Collecting build>=1.0.3
#   Downloading build-1.2.1-py3-none-any.whl (21 kB)
# Collecting overrides>=7.3.1
#   Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\asus\anaconda3\lib\site-packages (from chromadb) (3.10.7)
# Collecting opentelemetry-sdk>=1.2.0
#   Downloading opentelemetry_sdk-1.27.0-py3-none-any.whl (110 kB)
# Collecting pypika>=0.48.9
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#   Installing build dependencies: started
#   Installing build dependencies: still running...
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Collecting tqdm>=4.65.0
#   Downloading tqdm-4.66.5-py3-none-any.whl (78 kB)
# Collecting kubernetes>=28.1.0
#   Downloading kubernetes-30.1.0-py2.py3-none-any.whl (1.7 MB)
# Requirement already satisfied: PyYAML>=6.0.0 in c:\users\asus\anaconda3\lib\site-packages (from chromadb) (6.0)
# Collecting mmh3>=4.0.1
#   Downloading mmh3-4.1.0-cp39-cp39-win_amd64.whl (31 kB)
# Requirement already satisfied: numpy<2.0.0,>=1.22.5 in c:\users\asus\anaconda3\lib\site-packages (from chromadb) (1.26.3)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\asus\anaconda3\lib\site-packages (from chromadb) (1.59.2)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0
#   Downloading opentelemetry_instrumentation_fastapi-0.48b0-py3-none-any.whl (11 kB)
# Collecting opentelemetry-api>=1.2.0
#   Downloading opentelemetry_api-1.27.0-py3-none-any.whl (63 kB)
# Collecting fastapi>=0.95.2
#   Downloading fastapi-0.112.2-py3-none-any.whl (93 kB)
# Collecting typer>=0.9.0
#   Downloading typer-0.12.5-py3-none-any.whl (47 kB)
# Collecting onnxruntime>=1.14.1
#   Downloading onnxruntime-1.19.2-cp39-cp39-win_amd64.whl (11.1 MB)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\asus\anaconda3\lib\site-packages (from chromadb) (8.2.3)
# Collecting chroma-hnswlib==0.7.6
#   Downloading chroma_hnswlib-0.7.6-cp39-cp39-win_amd64.whl (151 kB)
# Collecting uvicorn[standard]>=0.18.3
#   Downloading uvicorn-0.30.6-py3-none-any.whl (62 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\asus\anaconda3\lib\site-packages (from chromadb) (4.8.0)
# Collecting tokenizers>=0.13.2
#   Downloading tokenizers-0.20.0-cp39-none-win_amd64.whl (2.3 MB)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\asus\anaconda3\lib\site-packages (from chromadb) (0.27.2)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.27.0-py3-none-any.whl (18 kB)
# Requirement already satisfied: importlib-resources in c:\users\asus\anaconda3\lib\site-packages (from chromadb) (6.1.1)
# Collecting bcrypt>=4.0.1
#   Downloading bcrypt-4.2.0-cp39-abi3-win_amd64.whl (151 kB)
# Requirement already satisfied: importlib-metadata>=4.6 in c:\users\asus\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (4.11.3)
# Requirement already satisfied: tomli>=1.1.0 in c:\users\asus\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (1.2.2)
# Requirement already satisfied: colorama in c:\users\asus\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (0.4.4)
# Requirement already satisfied: packaging>=19.1 in c:\users\asus\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (24.1)
# Collecting pyproject_hooks
#   Downloading pyproject_hooks-1.1.0-py3-none-any.whl (9.2 kB)
# Collecting starlette<0.39.0,>=0.37.2
#   Downloading starlette-0.38.4-py3-none-any.whl (71 kB)
# Requirement already satisfied: sniffio in c:\users\asus\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (1.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\asus\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.5)
# Requirement already satisfied: certifi in c:\users\asus\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (2021.10.8)
# Requirement already satisfied: idna in c:\users\asus\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (3.3)
# Requirement already satisfied: anyio in c:\users\asus\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (3.5.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\asus\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.14.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\asus\anaconda3\lib\site-packages (from importlib-metadata>=4.6->build>=1.0.3->chromadb) (3.7.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\asus\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\asus\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.58.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\asus\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\asus\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.8.2)
# Requirement already satisfied: requests in c:\users\asus\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.27.1)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\asus\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.23.4)
# Requirement already satisfied: requests-oauthlib in c:\users\asus\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.3.1)
# Requirement already satisfied: urllib3>=1.24.2 in c:\users\asus\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.26.9)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\asus\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\asus\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\asus\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.2.2)
# Requirement already satisfied: flatbuffers in c:\users\asus\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (23.5.26)
# Collecting coloredlogs
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Requirement already satisfied: protobuf in c:\users\asus\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (4.25.0)
# Requirement already satisfied: sympy in c:\users\asus\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.10.1)
# Collecting deprecated>=1.2.6
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Collecting importlib-metadata>=4.6
#   Downloading importlib_metadata-8.4.0-py3-none-any.whl (26 kB)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\asus\anaconda3\lib\site-packages (from deprecated>=1.2.6->opentelemetry-api>=1.2.0->chromadb) (1.12.1)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\asus\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.53.0)
# Collecting opentelemetry-proto==1.27.0
#   Downloading opentelemetry_proto-1.27.0-py3-none-any.whl (52 kB)
# Collecting opentelemetry-exporter-otlp-proto-common==1.27.0
#   Downloading opentelemetry_exporter_otlp_proto_common-1.27.0-py3-none-any.whl (17 kB)
# Collecting opentelemetry-semantic-conventions==0.48b0
#   Downloading opentelemetry_semantic_conventions-0.48b0-py3-none-any.whl (149 kB)
# Collecting opentelemetry-instrumentation==0.48b0
#   Downloading opentelemetry_instrumentation-0.48b0-py3-none-any.whl (29 kB)
# Collecting opentelemetry-util-http==0.48b0
#   Downloading opentelemetry_util_http-0.48b0-py3-none-any.whl (6.9 kB)
# Collecting opentelemetry-instrumentation-asgi==0.48b0
#   Downloading opentelemetry_instrumentation_asgi-0.48b0-py3-none-any.whl (15 kB)
# Requirement already satisfied: setuptools>=16.0 in c:\users\asus\anaconda3\lib\site-packages (from opentelemetry-instrumentation==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (61.2.0)
# Collecting asgiref~=3.0
#   Downloading asgiref-3.8.1-py3-none-any.whl (23 kB)
# Collecting monotonic>=1.5
#   Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Collecting backoff>=1.10.0
#   Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\asus\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.8)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\asus\anaconda3\lib\site-packages (from pydantic>=1.9->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\asus\anaconda3\lib\site-packages (from pydantic>=1.9->chromadb) (2.20.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\asus\anaconda3\lib\site-packages (from requests->kubernetes>=28.1.0->chromadb) (2.0.4)
# Collecting huggingface-hub<1.0,>=0.16.4
#   Downloading huggingface_hub-0.24.6-py3-none-any.whl (417 kB)
# Collecting fsspec>=2023.5.0
#   Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
# Requirement already satisfied: filelock in c:\users\asus\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.6.0)
# Collecting shellingham>=1.3.0
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Requirement already satisfied: rich>=10.11.0 in c:\users\asus\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb) (13.7.0)
# Requirement already satisfied: click>=8.0.0 in c:\users\asus\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb) (8.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\asus\anaconda3\lib\site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\asus\anaconda3\lib\site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\asus\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.9.0->chromadb) (0.1.2)
# Collecting httptools>=0.5.0
#   Downloading httptools-0.6.1-cp39-cp39-win_amd64.whl (60 kB)
# Collecting watchfiles>=0.13
#   Downloading watchfiles-0.24.0-cp39-none-win_amd64.whl (277 kB)
# Collecting python-dotenv>=0.13
#   Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Collecting websockets>=10.4
#   Downloading websockets-13.0.1-cp39-cp39-win_amd64.whl (152 kB)
# Collecting humanfriendly>=9.1
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Collecting pyreadline3
#   Downloading pyreadline3-3.4.1-py3-none-any.whl (95 kB)
# Requirement already satisfied: mpmath>=0.19 in c:\users\asus\anaconda3\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.2.1)
# Building wheels for collected packages: pypika
#   Building wheel for pypika (PEP 517): started
#   Building wheel for pypika (PEP 517): finished with status 'done'
#   Created wheel for pypika: filename=PyPika-0.48.9-py2.py3-none-any.whl size=53835 sha256=83cada264790086748ebd465e96a9278b993e72dc1ca16d1f7bdd33059215338
#   Stored in directory: c:\users\asus\appdata\local\pip\cache\wheels\f7\02\64\d541eac67ec459309d1fb19e727f58ecf7ffb4a8bf42d4cfe5
# Successfully built pypika
# Installing collected packages: importlib-metadata, deprecated, pyreadline3, opentelemetry-api, tqdm, opentelemetry-util-http, opentelemetry-semantic-conventions, opentelemetry-proto, opentelemetry-instrumentation, humanfriendly, fsspec, asgiref, websockets, watchfiles, uvicorn, starlette, shellingham, python-dotenv, pyproject-hooks, opentelemetry-sdk, opentelemetry-instrumentation-asgi, opentelemetry-exporter-otlp-proto-common, monotonic, huggingface-hub, httptools, coloredlogs, backoff, typer, tokenizers, pypika, posthog, overrides, opentelemetry-instrumentation-fastapi, opentelemetry-exporter-otlp-proto-grpc, onnxruntime, mmh3, kubernetes, fastapi, chroma-hnswlib, build, bcrypt, chromadb
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 4.11.3
#     Uninstalling importlib-metadata-4.11.3:
#       Successfully uninstalled importlib-metadata-4.11.3
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.64.0
#     Uninstalling tqdm-4.64.0:
#       Successfully uninstalled tqdm-4.64.0
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2022.2.0
#     Uninstalling fsspec-2022.2.0:
#       Successfully uninstalled fsspec-2022.2.0
#   Attempting uninstall: bcrypt
#     Found existing installation: bcrypt 3.2.0
#     Uninstalling bcrypt-3.2.0:
#       Successfully uninstalled bcrypt-3.2.0
# Successfully installed asgiref-3.8.1 backoff-2.2.1 bcrypt-4.2.0 build-1.2.1 chroma-hnswlib-0.7.6 chromadb-0.5.5 coloredlogs-15.0.1 deprecated-1.2.14 fastapi-0.112.2 fsspec-2024.9.0 httptools-0.6.1 huggingface-hub-0.24.6 humanfriendly-10.0 importlib-metadata-8.4.0 kubernetes-30.1.0 mmh3-4.1.0 monotonic-1.6 onnxruntime-1.19.2 opentelemetry-api-1.27.0 opentelemetry-exporter-otlp-proto-common-1.27.0 opentelemetry-exporter-otlp-proto-grpc-1.27.0 opentelemetry-instrumentation-0.48b0 opentelemetry-instrumentation-asgi-0.48b0 opentelemetry-instrumentation-fastapi-0.48b0 opentelemetry-proto-1.27.0 opentelemetry-sdk-1.27.0 opentelemetry-semantic-conventions-0.48b0 opentelemetry-util-http-0.48b0 overrides-7.7.0 posthog-3.6.3 pypika-0.48.9 pyproject-hooks-1.1.0 pyreadline3-3.4.1 python-dotenv-1.0.1 shellingham-1.5.4 starlette-0.38.4 tokenizers-0.20.0 tqdm-4.66.5 typer-0.12.5 uvicorn-0.30.6 watchfiles-0.24.0 websockets-13.0.1

# %%
from langchain_community.document_loaders import WebBaseLoader
loader = WebBaseLoader("https://jobs.nike.com/job/R-36827?from=job%20search%20funnel")
page_data = loader.load().pop().page_content
print(page_data)
# Out:
# Apply for Lead Software Engineer, ITC
#
# Search JobsSkip navigationSearch JobsNIKE, INC. JOBSContract JobsJoin The Talent CommunityLife @ NikeOverviewBenefitsBrandsOverviewJordanConverseTeamsOverviewAdministrative SupportAdvanced InnovationAir Manufacturing InnovationAviationCommunicationsCustomer ServiceDesignDigitalFacilitiesFinance & AccountingGovernment & Public AffairsHuman ResourcesInsights & AnalyticsLegalManufacturing & EngineeringMarketingMerchandisingPlanningPrivacyProcurementProduct Creation, Development & ManagementRetail CorporateRetail StoresSalesSocial & Community ImpactSports MarketingStrategic PlanningSupply Chain, Distribution & LogisticsSustainabilityTechnologyLocationsOverviewNike WHQNike New York HQEHQ: Hilversum, The NetherlandsELC: Laakdal, BelgiumGreater China HQDiversity, Equity & InclusionOverviewMilitary InclusionDisability InclusionIndigenous InclusionInternshipsTechnologyLead Software Engineer, ITCKarnataka, IndiaBecome a Part of the NIKE, Inc. TeamNIKE, Inc. does more than outfit the world’s best athletes. It is a place to explore potential, obliterate boundaries and push out the edges of what can be. The company looks for people who can grow, think, dream and create. Its culture thrives by embracing diversity and rewarding imagination. The brand seeks achievers, leaders and visionaries. At NIKE, Inc. it’s about each person bringing skills and passion to a challenging and constantly evolving game.NIKE is a technology company. From our flagship website and five-star mobile apps to developing products, managing big data and providing leading edge engineering and systems support, our teams at NIKE Global Technology exist to revolutionize the future at the confluence of tech and sport. We invest and develop advances in technology and employ the most creative people in the world, and then give them the support to constantly innovate, iterate and serve consumers more directly and personally.  Our teams are innovative, diverse, multidisciplinary and collaborative, taking technology into the future and bringing the world with it.Supply Chain & Planning Technology (SCPT) team under GlobaL Technology (GT) at Nike  is implementing Integrated Business Planning across demand and supply management. Our vision is to optimize demand and supply to serve customers and drive profitable growth through Merchandize Financial Planning and Assortment planning for Nike Consumer Channels and its Partners. Primary focus is to build technology platforms harnessing the data, art and science to drive better business decisions and outcomes. We will do this by creating an environment where everyone thrives with a growth mindset culture with smart risk taking, measurement and continuous learning. Our products will be driven by Customer focus, User centric design and mindset.WHO WE ARE LOOKING FORIn this role we are looking for a high potential Lead Engineer with strong Planning domain expertise to lead and mentor a team of engineers with a focus to develop solutions for the various products of Demand & Supply Planning capability. As a Lead Engineer you are thoughtful, aspirational and adept at solutioning, architecture and hands on delivery.Advocate and implement business transformation solutions and best practices.Advocate DevOps practices & mindset and strong culture of innovationWHAT YOU WILL WORK ONDemand  & Supply planning application deisgn and implementation with emphasis on distributed systems concepts.Implement business solutions leveraging custom data platform and O9  platform.Design, develop, configure ,review code, and deploy cloud-based products.Drive engineering activities from designing through deployment while adhering to established Architectural guidelines and principles.Collaborate with other stake holders across the Enterprise, Planning technical platforms, technology stack and solutions to meet demand of our ever-changing consumer needs.Provide insights for developing and communicating Technology Strategy and roadmap; ensure alignment to planing tec ...
#
# * This overview explains our hiring process for corporate roles. Note there may be different hiring steps involved for non-corporate roles.Start nowBenefitsWhether it’s transportation or financial health, we continually invest in our employees to help them achieve greatness — inside and outside of work. All who work here should be able to realize their full potential.Employee Assistance ProgramHolidaysMedical PlanPaid Time Off (PTO)Product DiscountsLearn moreGIFT CARDSPROMOTIONSFIND A STORESIGN UP FOR EMAILBECOME A MEMBERNIKE JOURNALSEND US FEEDBACKGET HELPGET HELPOrder StatusShipping and DeliveryReturnsPayment OptionsGift Cards BalanceContact UsABOUT NIKEABOUT NIKENewsCareersInvestorsPurposeSustainabilityUnited States© 2024 Nike, Inc. All Rights ReservedGuidesNike AdaptNike Air MaxNike FlyleatherNike ReactSpace HippieNike AirNike FlyEaseNike Free Nike VaporflyNike Air Force 1 Nike FlyknitNike JoyrideNike ZoomXTerms of SaleTerms of UseNike Privacy PolicyYour Privacy ChoicesCA Supply Chain Act

# %%
# !pip install langchain_community
# Out:
# Collecting langchain_community
#   Downloading langchain_community-0.2.16-py3-none-any.whl (2.3 MB)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in c:\users\asus\anaconda3\lib\site-packages (from langchain_community) (8.2.3)
# Requirement already satisfied: langchain<0.3.0,>=0.2.16 in c:\users\asus\anaconda3\lib\site-packages (from langchain_community) (0.2.16)
# Requirement already satisfied: numpy<2,>=1 in c:\users\asus\anaconda3\lib\site-packages (from langchain_community) (1.26.3)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\asus\anaconda3\lib\site-packages (from langchain_community) (1.4.32)
# Requirement already satisfied: requests<3,>=2 in c:\users\asus\anaconda3\lib\site-packages (from langchain_community) (2.27.1)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in c:\users\asus\anaconda3\lib\site-packages (from langchain_community) (0.1.112)
# Collecting dataclasses-json<0.7,>=0.5.7
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\asus\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\asus\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\asus\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\asus\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\asus\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\asus\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\asus\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\asus\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\asus\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\asus\anaconda3\lib\site-packages)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\asus\anaconda3\lib\site-packages (from langchain_community) (6.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\asus\anaconda3\lib\site-packages (from langchain_community) (3.10.5)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.38 in c:\users\asus\anaconda3\lib\site-packages (from langchain_community) (0.2.38)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\asus\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.2.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in c:\users\asus\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (4.0.1)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\asus\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\asus\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (5.1.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\asus\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (21.4.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\asus\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.4.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\asus\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.6.3)
# Requirement already satisfied: typing-extensions>=3.6.5 in c:\users\asus\anaconda3\lib\site-packages (from async-timeout<5.0,>=4.0->aiohttp<4.0.0,>=3.8.3->langchain_community) (4.8.0)
# Collecting typing-inspect<1,>=0.4.0
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Collecting marshmallow<4.0.0,>=3.18.0
#   Downloading marshmallow-3.22.0-py3-none-any.whl (49 kB)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in c:\users\asus\anaconda3\lib\site-packages (from langchain<0.3.0,>=0.2.16->langchain_community) (0.2.4)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\asus\anaconda3\lib\site-packages (from langchain<0.3.0,>=0.2.16->langchain_community) (2.8.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\asus\anaconda3\lib\site-packages (from langchain-core<0.3.0,>=0.2.38->langchain_community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\asus\anaconda3\lib\site-packages (from langchain-core<0.3.0,>=0.2.38->langchain_community) (24.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\asus\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.38->langchain_community) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\asus\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.0->langchain_community) (3.10.7)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\asus\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.0->langchain_community) (0.27.2)
# Requirement already satisfied: sniffio in c:\users\asus\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain_community) (1.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\asus\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain_community) (1.0.5)
# Requirement already satisfied: certifi in c:\users\asus\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain_community) (2021.10.8)
# Requirement already satisfied: anyio in c:\users\asus\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain_community) (3.5.0)
# Requirement already satisfied: idna in c:\users\asus\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain_community) (3.3)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\asus\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain_community) (0.14.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\asus\anaconda3\lib\site-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.16->langchain_community) (2.20.1)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\asus\anaconda3\lib\site-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.16->langchain_community) (0.7.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\asus\anaconda3\lib\site-packages (from requests<3,>=2->langchain_community) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\asus\anaconda3\lib\site-packages (from requests<3,>=2->langchain_community) (2.0.4)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\asus\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain_community) (1.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\asus\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community) (0.4.3)
# Installing collected packages: typing-inspect, marshmallow, dataclasses-json, langchain-community
# Successfully installed dataclasses-json-0.6.7 langchain-community-0.2.16 marshmallow-3.22.0 typing-inspect-0.9.0

# %%
from langchain_core.prompts import PromptTemplate
prompt_extract = PromptTemplate.from_template(
        """
        ### SCRAPED TEXT FROM WEBSITE:
        {page_data}
        ### INSTRUCTION:
        The scraped text is from the career's page of a website.
        Your job is to extract the job postings and return them in JSON format containing the 
        following keys: `role`, `experience`, `skills` and `description`.
        Only return the valid JSON.
        ### VALID JSON (NO PREAMBLE):    
        """
)

chain_extract = prompt_extract | llm 
res = chain_extract.invoke(input={'page_data':page_data})
print(res.content)
# Out:
# ```
# {
#   "role": "Lead Software Engineer, ITC",
#   "experience": "8+ years",
#   "skills": [
#     "Technical architecture",
#     "Design",
#     "Development",
#     "Demand or inventory planning products/applications",
#     "Integrated Business Planning solutions like O9",
#     "PL/SQL",
#     "Cloud environments such as AWS, Azure or GCP",
#     "Scrum and other Agile processes",
#     "Jira, Git/SVN, Jenkins, CI/CD pipelines"
#   ],
#   "description": "Lead and mentor a team of engineers with a focus to develop solutions for the various products of Demand & Supply Planning capability. Advocate and implement business transformation solutions and best practices. Advocate DevOps practices & mindset and strong culture of innovation."
# }
# ```

# %%
from langchain_core.output_parsers import JsonOutputParser

json_parser = JsonOutputParser()
json_res = json_parser.parse(res.content)
json_res
# Out:
# {'role': 'Lead Software Engineer, ITC',
#  'experience': '8+ years',
#  'skills': ['Technical architecture',
#   'Design',
#   'Development',
#   'Demand or inventory planning products/applications',
#   'Integrated Business Planning solutions like O9',
#   'PL/SQL',
#   'Cloud environments such as AWS, Azure or GCP',
#   'Scrum and other Agile processes',
#   'Jira, Git/SVN, Jenkins, CI/CD pipelines'],
#  'description': 'Lead and mentor a team of engineers with a focus to develop solutions for the various products of Demand & Supply Planning capability. Advocate and implement business transformation solutions and best practices. Advocate DevOps practices & mindset and strong culture of innovation.'}

# %%
import pandas as pd
df = pd.read_csv('my_portfolio.csv')

# %%
df
# Out:
#                                Techstack  \
# 0                React, Node.js, MongoDB
# 1               Angular,.NET, SQL Server
# 2      Vue.js, Ruby on Rails, PostgreSQL
# 3                  Python, Django, MySQL
# 4              Java, Spring Boot, Oracle
# 5             Flutter, Firebase, GraphQL
# 6                  WordPress, PHP, MySQL
# 7                    Magento, PHP, MySQL
# 8         React Native, Node.js, MongoDB
# 9                  iOS, Swift, Core Data
# 10       Android, Java, Room Persistence
# 11             Kotlin, Android, Firebase
# 12       Android TV, Kotlin, Android NDK
# 13                     iOS, Swift, ARKit
# 14        Cross-platform, Xamarin, Azure
# 15          Backend, Kotlin, Spring Boot
# 16         Frontend, TypeScript, Angular
# 17    Full-stack, JavaScript, Express.js
# 18  Machine Learning, Python, TensorFlow
# 19               DevOps, Jenkins, Docker
#
#                                                 Links
# 0                 https://example.com/react-portfolio
# 1               https://example.com/angular-portfolio
# 2                   https://example.com/vue-portfolio
# 3                https://example.com/python-portfolio
# 4                  https://example.com/java-portfolio
# 5               https://example.com/flutter-portfolio
# 6             https://example.com/wordpress-portfolio
# 7               https://example.com/magento-portfolio
# 8          https://example.com/react-native-portfolio
# 9                   https://example.com/ios-portfolio
# 10              https://example.com/android-portfolio
# 11       https://example.com/kotlin-android-portfolio
# 12           https://example.com/android-tv-portfolio
# 13               https://example.com/ios-ar-portfolio
# 14              https://example.com/xamarin-portfolio
# 15       https://example.com/kotlin-backend-portfolio
# 16  https://example.com/typescript-frontend-portfolio
# 17        https://example.com/full-stack-js-portfolio
# 18            https://example.com/ml-python-portfolio
# 19               https://example.com/devops-portfolio

# %%
import uuid
import chromadb

client = chromadb.PersistentClient('vectorstore')
collection = client.get_or_create_collection(name="portfolio")

if not collection.count():
    for _, row in df.iterrows():
        collection.add(documents=row["Techstack"],
                       metadatas={"links": row["Links"]},
                       ids=[str(uuid.uuid4())])

# %%
links = collection.query(query_texts=job['skills'], n_results=2).get('metadatas', [])
links
# Out:
# [[{'links': 'https://example.com/ml-python-portfolio'},
#   {'links': 'https://example.com/typescript-frontend-portfolio'}],
#  [{'links': 'https://example.com/magento-portfolio'},
#   {'links': 'https://example.com/android-portfolio'}],
#  [{'links': 'https://example.com/ios-ar-portfolio'},
#   {'links': 'https://example.com/ml-python-portfolio'}],
#  [{'links': 'https://example.com/ml-python-portfolio'},
#   {'links': 'https://example.com/vue-portfolio'}],
#  [{'links': 'https://example.com/android-portfolio'},
#   {'links': 'https://example.com/angular-portfolio'}],
#  [{'links': 'https://example.com/magento-portfolio'},
#   {'links': 'https://example.com/wordpress-portfolio'}],
#  [{'links': 'https://example.com/xamarin-portfolio'},
#   {'links': 'https://example.com/devops-portfolio'}],
#  [{'links': 'https://example.com/devops-portfolio'},
#   {'links': 'https://example.com/kotlin-backend-portfolio'}],
#  [{'links': 'https://example.com/devops-portfolio'},
#   {'links': 'https://example.com/vue-portfolio'}]]

# %%
job = json_res
job['skills']
# Out:
# ['Technical architecture',
#  'Design',
#  'Development',
#  'Demand or inventory planning products/applications',
#  'Integrated Business Planning solutions like O9',
#  'PL/SQL',
#  'Cloud environments such as AWS, Azure or GCP',
#  'Scrum and other Agile processes',
#  'Jira, Git/SVN, Jenkins, CI/CD pipelines']

# %%
prompt_email = PromptTemplate.from_template(
        """
        ### JOB DESCRIPTION:
        {job_description}
        
        ### INSTRUCTION:
        You are Mohan, a business development executive at AtliQ. AtliQ is an AI & Software Consulting company dedicated to facilitating
        the seamless integration of business processes through automated tools. 
        Over our experience, we have empowered numerous enterprises with tailored solutions, fostering scalability, 
        process optimization, cost reduction, and heightened overall efficiency. 
        Your job is to write a cold email to the client regarding the job mentioned above describing the capability of AtliQ 
        in fulfilling their needs.
        Also add the most relevant ones from the following links to showcase Atliq's portfolio: {link_list}
        Remember you are Mohan, BDE at AtliQ. 
        Do not provide a preamble.
        ### EMAIL (NO PREAMBLE):
        
        """
        )

chain_email = prompt_email | llm
res = chain_email.invoke({"job_description": str(job), "link_list": links})
print(res.content)
# Out:
# Subject: Expert Software Development Solutions for ITC Lead Software Engineer Role
#
# Dear Hiring Manager,
#
# I came across the job description for the Lead Software Engineer, ITC role at your esteemed organization, and I am excited to introduce AtliQ, an AI & Software Consulting company that can cater to your software development needs.
#
# With 8+ years of experience in technical architecture, design, development, and demand or inventory planning products/applications, our team of experts can seamlessly integrate with your existing team to develop innovative solutions for your Demand & Supply Planning capability. Our proficiency in Integrated Business Planning solutions like O9, PL/SQL, and cloud environments such as AWS, Azure, or GCP aligns perfectly with your requirements.
#
# At AtliQ, we advocate DevOps practices and a strong culture of innovation, ensuring that our solutions are scalable, efficient, and cost-effective. Our expertise in Scrum and other Agile processes, Jira, Git/SVN, Jenkins, and CI/CD pipelines enables us to deliver high-quality solutions that meet your business needs.
#
# Our portfolio showcases our capabilities in software development, including:
#
# * DevOps solutions: https://example.com/devops-portfolio
# * Cloud environments: Our experience with AWS, Azure, and GCP enables us to develop scalable and efficient solutions.
# * Agile development: Our expertise in Scrum and other Agile processes ensures that our solutions are delivered on time and meet your business needs.
#
# We have empowered numerous enterprises with tailored solutions, fostering scalability, process optimization, cost reduction, and heightened overall efficiency. Our team is committed to delivering innovative solutions that meet your business needs.
#
# If you're looking for a reliable partner to develop solutions for your Demand & Supply Planning capability, I'd be happy to schedule a call to discuss how AtliQ can help.
#
# Please feel free to contact me at your convenience.
#
# Best regards,
#
# Mohan
# Business Development Executive
# AtliQ
